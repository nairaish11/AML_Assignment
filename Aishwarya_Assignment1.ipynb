# %% [markdown]
# <a href="https://colab.research.google.com/github/nairaish11/AML_Assignment/blob/main/Aishwarya_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('customer_churn.csv')

# %%
data
# Out:
#                 Names   Age  Total_Purchase  Account_Manager  Years  \
# 0    Cameron Williams  42.0        11066.80                0   7.22
# 1       Kevin Mueller  41.0        11916.22                0   6.50
# 2         Eric Lozano  38.0        12884.75                0   6.67
# 3       Phillip White  42.0         8010.76                0   6.71
# 4      Cynthia Norton  37.0         9191.58                0   5.56
# ..                ...   ...             ...              ...    ...
# 895       Paul Miller  42.0        12800.82                1   3.62
# 896    Natalie Hodges  52.0         9893.92                0   6.91
# 897         Ana Smith  45.0        12056.18                0   5.46
# 898    Justin Leonard  51.0         6517.93                1   5.47
# 899   Joseph Williams  39.0         9315.60                1   5.02
#
#      Num_Sites         Onboard_date  \
# 0          8.0  2013-08-30 07:00:40
# 1         11.0  2013-08-13 00:38:46
# 2         12.0  2016-06-29 06:20:07
# ...

# %%
data.columns
# Out:
# Index(['Names', 'Age', 'Total_Purchase', 'Account_Manager', 'Years',
#        'Num_Sites', 'Onboard_date', 'Location', 'Company', 'Churn'],
#       dtype='object')

# %%
data.drop(labels=[data.columns[0],data.columns[6], data.columns[7], data.columns[8]], axis=1, inplace=True)

# %%
data
# Out:
#       Age  Total_Purchase  Account_Manager  Years  Num_Sites  Churn
# 0    42.0        11066.80                0   7.22        8.0      1
# 1    41.0        11916.22                0   6.50       11.0      1
# 2    38.0        12884.75                0   6.67       12.0      1
# 3    42.0         8010.76                0   6.71       10.0      1
# 4    37.0         9191.58                0   5.56        9.0      1
# ..    ...             ...              ...    ...        ...    ...
# 895  42.0        12800.82                1   3.62        8.0      0
# 896  52.0         9893.92                0   6.91        7.0      0
# 897  45.0        12056.18                0   5.46        4.0      0
# 898  51.0         6517.93                1   5.47       10.0      0
# 899  39.0         9315.60                1   5.02       10.0      0
#
# [900 rows x 6 columns]

# %%
Y = data['Churn']

# %%
# Y.replace(to_replace=['B','M'], value=[0,1], inplace=True)

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 895    0
# 896    0
# 897    0
# 898    0
# 899    0
# Name: Churn, Length: 900, dtype: int64

# %%
Y = np.array(Y)

# %%
Y = Y.reshape(Y.shape[0], 1)

# %%
Y.shape
# Out:
# (900, 1)

# %%
X = data.iloc[:, :-1].values

# %%
X
# Out:
# array([[4.200000e+01, 1.106680e+04, 0.000000e+00, 7.220000e+00,
#         8.000000e+00],
#        [4.100000e+01, 1.191622e+04, 0.000000e+00, 6.500000e+00,
#         1.100000e+01],
#        [3.800000e+01, 1.288475e+04, 0.000000e+00, 6.670000e+00,
#         1.200000e+01],
#        ...,
#        [4.500000e+01, 1.205618e+04, 0.000000e+00, 5.460000e+00,
#         4.000000e+00],
#        [5.100000e+01, 6.517930e+03, 1.000000e+00, 5.470000e+00,
#         1.000000e+01],
#        [3.900000e+01, 9.315600e+03, 1.000000e+00, 5.020000e+00,
#         1.000000e+01]])

# %%
X.shape
# Out:
# (900, 5)

# %%
X = (X - np.mean(X, axis=0))// np.std(X, axis=0)

# %%
theta_initial = np.random.normal(loc = 0, scale=1, size=(X.shape[1],1))

# %%
theta_initial
# Out:
# array([[-0.08031944],
#        [ 0.50679947],
#        [-0.56197691],
#        [ 0.91984843],
#        [ 0.53573214]])

# %%
theta0_initial = 0

# %%
def sigmoid(theta0, theta):
    return 1/(1 + np.exp(-(theta0 + np.matmul(X, theta))))

# %%
# 1 in notes
def del_L_by_del_theta0(theta0, theta):

    return np.sum(sigmoid(theta0, theta) - Y)

# %%
# 2 in notes
def del_L_by_del_theta(theta0, theta):

    return np.matmul((sigmoid(theta0, theta) - Y).T, X).T    
    # first its (569,1)
    # after transpose(1, 569)

# %%
def binary_cross_entropy(theta0, theta):

    return -(np.dot(Y.T, np.log(sigmoid(theta0, theta)))  +  np.dot((1-Y).T, np.log(1-sigmoid(theta0, theta))))

# %%
max_iter = 500000
epsilon = 0.000001
tol = 0.0001
counter = 0

while counter<=max_iter:

    theta0_final = theta0_initial - epsilon * del_L_by_del_theta0(theta0_initial, theta_initial)
    theta_final = theta_initial - epsilon * del_L_by_del_theta(theta0_initial, theta_initial)

    if np.abs(binary_cross_entropy(theta0_final, theta_final) - binary_cross_entropy(theta0_initial, theta_initial)) < tol:
        break

    print('The value of Binary Cross Entropy at Epoch # {} is {}'.format(counter, binary_cross_entropy(theta0_initial, theta_initial)))

    theta0_initial = theta0_final
    theta_initial = theta_final

    counter += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# The value of Binary Cross Entropy at Epoch # 37273 is [[248.42717055]]
# The value of Binary Cross Entropy at Epoch # 37274 is [[248.42701932]]
# The value of Binary Cross Entropy at Epoch # 37275 is [[248.42686811]]
# The value of Binary Cross Entropy at Epoch # 37276 is [[248.4267169]]
# The value of Binary Cross Entropy at Epoch # 37277 is [[248.42656571]]
# The value of Binary Cross Entropy at Epoch # 37278 is [[248.42641454]]
# The value of Binary Cross Entropy at Epoch # 37279 is [[248.42626337]]
# The value of Binary Cross Entropy at Epoch # 37280 is [[248.42611222]]
# The value of Binary Cross Entropy at Epoch # 37281 is [[248.42596108]]
# The value of Binary Cross Entropy at Epoch # 37282 is [[248.42580996]]
# The value of Binary Cross Entropy at Epoch # 37283 is [[248.42565885]]
# The value of Binary Cross Entropy at Epoch # 37284 is [[248.42550775]]
# ...
